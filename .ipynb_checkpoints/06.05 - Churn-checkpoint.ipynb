# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel("2018.xlsx")
df
# Out:
#             Организация      Код             Город          Тип  Дата откл.  \
# 0                Алматы   7501.0            Алматы          МСБ  01.01.2018
# 1                 Ала-W  11860.0            Алматы  Частный дом  01.01.2018
# 2                Алматы   8222.0            Алматы     Квартира  01.01.2018
# 3                Алматы   6766.0            Алматы           КБ  01.01.2018
# 4                Алматы   1744.0            Алматы  Частный дом  01.01.2018
# 5              Каскелен   7733.0          Каскелен  Частный дом  01.01.2018
# 6                Алматы   3088.0            Алматы     Квартира  01.01.2018
# 7                Алматы   5987.0            Алматы     Квартира  01.01.2018
# 8                Алматы   5660.0            Алматы     Квартира  01.01.2018
# 9                Алматы   5086.0            Алматы     Квартира  01.01.2018
# 10               Алматы   5087.0            Алматы     Квартира  01.01.2018
# ...

# %%
df['Тип'].value_counts()
# Out:
# МСБ            1742
# КБ             1460
# Квартира        820
# Частный дом     466
# Name: Тип, dtype: int64

# %%
df_ph = df[df['Тип']=="Квартира" or df['Тип']=="Частный дом"]

# %%
ax = sns.swarmplot(x="Причина", y="Сумма", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Нет необходимости'),
#  Text(0,0,'Отключение по распоряжени'),
#  Text(0,0,'Переоформление'),
#  Text(0,0,'Переезд'),
#  Text(0,0,'Экономические причины'),
#  Text(0,0,'Временное отключение'),
#  Text(0,0,'Продажа недвижимости/смен'),
#  Text(0,0,'Плохое качество услуг'),
#  Text(0,0,'Разное')]

# %%
sns.jointplot(x="Причина", y="Тип")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-63951bce0be4> in <module>
# ----> 1 sns.jointplot(x="Причина", y="Тип")
#
# ~\Anaconda3\envs\def\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2282     grid = JointGrid(x, y, data, dropna=dropna,
#    2283                      height=height, ratio=ratio, space=space,
# -> 2284                      xlim=xlim, ylim=ylim)
#    2285
#    2286     # Plot the data using the grid
#
# ~\Anaconda3\envs\def\lib\site-packages\seaborn\axisgrid.py in __init__(self, x, y, data, height, ratio, space, dropna, xlim, ylim, size)
#    1707             if isinstance(var, string_types):
#    1708                 err = "Could not interpret input '{}'".format(var)
# ...
